# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
x = np.zeros((20000,1),float)
x[0] = 0.1
a = -2
for i in range(len(x)-1):
    #print(i,x[i])
    x[i+1] = 1.0+a/x[i]
plt.plot(x)
#
import sympy as sy
z = sy.Symbol('z')
sy.solve(z-(1+a/z),z)
# Out:
# [1/2 - sqrt(7)*I/2, 1/2 + sqrt(7)*I/2]
